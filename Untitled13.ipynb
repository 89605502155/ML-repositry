# %%
# !git clone https://github.com/89605502155/ML-repositry.git
# Out:
# Cloning into 'ML-repositry'...
# remote: Enumerating objects: 531, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 531 (delta 14), reused 34 (delta 10), pack-reused 492
# Receiving objects: 100% (531/531), 57.57 MiB | 33.03 MiB/s, done.
# Resolving deltas: 100% (284/284), done.

# %%
# !pip3 install npls
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting npls
#   Downloading npls-0.0.2.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from npls) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from npls) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->npls) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->npls) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->npls) (3.1.0)
# Building wheels for collected packages: npls
#   Building wheel for npls (setup.py) ... done
#   Created wheel for npls: filename=npls-0.0.2-py3-none-any.whl size=15706 sha256=96bf2e72a6b79168755d5d6694eeaa144d72a40e86dce9d069042ebfd8b58ddd
#   Stored in directory: /root/.cache/pip/wheels/f2/79/d4/fb9142af0220ae783af3181214b61ed13d8bb19a3b2029ad62
# Successfully built npls
# Installing collected packages: npls
# Successfully installed npls-0.0.2

# %%
import numpy as np
from npls import npls
import pickle as pkl
import pandas as pd
import warnings 
from glob import glob
import os
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from numpy import linalg as LA
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator
from sklearn.base import RegressorMixin
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import matplotlib as mpl
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, make_scorer
import sklearn

# %%
# d=np.load('ML-repositry/X_marat_2023.npz')
# d=np.load('ML-repositry/Xzero_marat.npz')
d = pkl.load(open('ML-repositry/X_new.pkl.gz', 'rb'))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-6cfccdaeb8b0> in <cell line: 1>()
# ----> 1 d.files
#
# AttributeError: 'dict' object has no attribute 'files'

# %%
# x1=d['arr_0']
# x1=d['x1']
x1=d['X']

# %%
h=d['excitation']
v=d['emission']

# %%
h
# Out:
# array([245., 250., 255., 260., 265., 270., 275., 280., 285., 290., 295.,
#        300., 305., 310., 315., 320., 325., 330., 335., 340., 345., 350.,
#        355., 360., 365., 370., 375., 380., 385., 390., 395., 400., 405.,
#        410., 415., 420., 425., 430., 435., 440., 445., 450., 455., 460.,
#        465., 470., 475., 480., 485., 490., 495., 500.])

# %%
x1.shape
# Out:
# (35, 206, 52)

# %%
# x1=x1[:,:,4:]

# %%
x1-=x1.mean(axis=0)

# %%
plt.imshow(x1[0,:,:],aspect='auto')
plt.show()

# %%
import matplotlib.gridspec as gridspec

# %%
fg = plt.figure(figsize=(15, 7.5),constrained_layout=False)
gs = gridspec.GridSpec(ncols=1, nrows=1, figure=fg)
#plt.title("Центрирование спектра образца 5",  {'fontname':'Times New Roman'}, fontsize=28,loc="center" ,pad=45)

plt.subplots_adjust(wspace=0, hspace=0)

fig_ax_1 = fg.add_subplot(gs[0])
#plt.imshow(on+tw+th+fo+trtrt,aspect="auto", origin='lower')
plt.imshow(x1[0,:,:],aspect="auto", origin='lower',extent=[h[0],h[-1],v[0],v[-1]])
plt.ylabel("Emission" , fontsize=25,labelpad=15)
plt.xlabel("Excitation",  fontsize=25,labelpad=15)
plt.title("EEM ",  {'fontname':'Times New Roman'}, fontsize=28,loc="center" ,pad=15)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=20)
#plt.yticks(range(240,690,50),fontsize=20)
fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=20)
fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=20)
#plt.xticks(indexx,lower,fontsize=20)
# plt.savefig('Experimental_loadings_without_constant_centering.png', format='png', dpi=300)
# plt.savefig("Experimental_loadings_without_constant_centering.svg", format="svg")

plt.show();
# Out:
# <ipython-input-173-3f346f8c27bf>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig_ax_1.set_yticklabels(fig_ax_1.get_yticklabels(), fontsize=20)
# <ipython-input-173-3f346f8c27bf>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig_ax_1.set_xticklabels(fig_ax_1.get_xticklabels(), fontsize=20)
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %%
import numpy as np
from gzip import open # NB: overrides standard open()
import pickle as pkl
import pandas as pd
import warnings 
from glob import glob
import os

# %%
Ydata = pkl.load(open('ML-repositry/y.pkl.gz', 'rb'))

# %%
y1=np.array(Ydata.Tyr)

# %%
y2=y1[::-1]

# %%
x1-=x1.mean(axis=0)

# %%
a1=y1.mean()
# y1-=a1
# y2-=a1

# %%
y1-=a1

# %%
a1,y1
# Out:
# (2.5084838423733027,
#  array([ 1.21016089, -0.98923039,  1.00584192,  1.59932433, -0.11068209,
#         -0.73729198, -0.42772101,  1.45058259, -1.33615106,  0.53762003,
#          0.83699859,  0.02248293, -1.66972105,  1.75275873,  0.06923475,
#         -1.17217001, -0.34376058,  1.03834383, -0.66297443,  1.43394175,
#         -1.04992327,  0.64390322,  1.32761058,  0.45089293, -0.84753151,
#         -1.52952494, -1.83347624,  0.74589251, -0.53285847,  1.82864036,
#         -1.59138131, -0.25263732,  0.17499349,  0.36637981, -1.40856758]))

# %%
npls1=npls()
scoring={'mse': make_scorer(mean_squared_error),'r2':'r2'}
parametrsNames={'n_components': range(15),
                'a': [0.3]}

# %%
gridCought=GridSearchCV(npls1, parametrsNames, cv=5, scoring=scoring,refit='r2', return_train_score=True)
#gridCought.fit(X_train.copy(),y_train.copy())

gridCought.fit(x1, y1)
r2_p=gridCought.score(x1, y1)
mse_cv=gridCought.cv_results_[ "mean_test_mse" ]
mse_c=gridCought.cv_results_[ "mean_train_mse" ]
r2_cv=gridCought.cv_results_[ "mean_test_r2" ]
r2_c=gridCought.cv_results_[ "mean_train_r2" ]
predictors=gridCought.predict(x1)

# %%
plt.plot(r2_p,".",color='green')
plt.plot(r2_c,".",color='blue')
plt.plot(r2_cv,".",color='red')
plt.show()

# %%
plt.plot(y1,y1)
plt.plot(y1,predictors,".",color="red")
plt.show()

# %%
gridCought.best_params_
# Out:
# {'a': 0.3, 'n_components': 3}

# %%
npls_=npls(n_components=3,a=0.3)
npls_.fit(x1,y1)
# Out:
# npls(a=0.3, n_components=3)

# %%
npls_.w_i
# Out:
# array([[[-1.31241105e-01],
#         [-2.04184008e-01],
#         [-2.85493932e-01],
#         [-3.69507756e-01],
#         [-4.74857462e-01],
#         [-5.36823540e-01],
#         [-4.21796050e-01],
#         [-1.60746825e-01],
#         [-7.16960788e-02],
#         [-2.02586346e-02],
#         [-6.25106211e-03],
#         [-4.43916919e-03],
#         [-1.13807855e-03],
#         [-5.66391507e-04],
#         [-2.40792676e-04],
#         [-2.65038293e-04],
#         [-2.33795157e-04],
#         [-1.43472607e-04],
#         [-1.86694566e-04],
#         [-1.64840767e-04],
#         [-1.20468083e-04],
#         [-9.67982715e-05],
#         [-8.86189226e-05],
#         [-8.86614808e-05],
#         [-5.75008515e-05],
#         [-2.76012915e-05],
#         [-3.91484760e-05],
#         [-4.55543609e-05],
#         [-2.81458339e-05],
#         [-3.23901180e-05],
#         [-2.45529875e-05],
#         [-5.08740213e-05],
#         [-6.97140164e-05],
#         [-1.35902864e-04],
#         [-1.71640898e-04],
#         [-2.13663979e-04],
#         [-2.44782212e-04],
#         [-3.13999761e-04],
#         [-4.64794386e-04],
#         [-6.87985632e-04],
#         [-1.04124281e-03],
#         [-1.40402805e-03],
#         [-1.54458794e-03],
#         [-1.41264319e-03],
#         [-1.04171719e-03],
#         [-5.19778363e-04],
#         [-2.05966400e-04],
#         [-1.09777836e-04],
#         [-1.03980107e-04],
#         [-1.26822660e-04],
#         [-1.27573439e-04],
#         [-1.80073962e-04]],
#
#        [[ 2.17880458e-01],
#         [ 2.74207478e-01],
#         [ 3.28347494e-01],
#         [ 3.68584820e-01],
#         [ 4.07897861e-01],
#         [ 4.28639532e-01],
#         [ 3.83519484e-01],
#         [ 2.83716996e-01],
#         [ 1.99290206e-01],
#         [ 1.12654449e-01],
#         [ 5.36792031e-02],
#         [ 2.48325141e-02],
#         [ 8.22125587e-03],
#         [ 1.58099690e-03],
#         [-8.41374345e-05],
#         [-3.49595975e-04],
#         [-2.86127087e-04],
#         [-2.43185552e-04],
#         [-2.74542017e-04],
#         [-1.97431268e-04],
#         [-4.02896164e-05],
#         [ 4.84400308e-07],
#         [-1.50703062e-06],
#         [ 1.75392620e-05],
#         [ 2.31213338e-05],
#         [ 5.65230935e-05],
#         [-1.18735279e-05],
#         [-3.11611746e-05],
#         [ 3.63899454e-05],
#         [ 7.19828486e-06],
#         [-9.23454227e-06],
#         [-1.01412463e-05],
#         [ 7.15793583e-06],
#         [ 4.02670652e-05],
#         [ 3.16019264e-05],
#         [ 3.13664732e-05],
#         [ 4.34059767e-05],
#         [ 6.10488560e-05],
#         [ 8.48617787e-05],
#         [ 1.21550925e-04],
#         [ 1.78528835e-04],
#         [ 2.30942916e-04],
#         [ 2.50422434e-04],
#         [ 2.31391787e-04],
#         [ 1.70148850e-04],
#         [ 8.63215141e-05],
#         [ 3.59621750e-05],
#         [ 2.24241981e-05],
#         [ 1.88021853e-05],
#         [ 2.21346735e-05],
#         [ 1.39824170e-05],
#         [ 2.93880008e-05]],
#
#        [[ 3.83172895e-01],
#         [ 3.20316496e-01],
#         [ 3.24523749e-01],
#         [ 3.01202033e-01],
#         [ 3.34598201e-01],
#         [ 3.36205103e-01],
#         [ 2.96892560e-01],
#         [ 2.55027142e-01],
#         [ 2.07184259e-01],
#         [ 1.80399812e-01],
#         [ 1.27167229e-01],
#         [ 1.25064459e-01],
#         [ 1.05444409e-01],
#         [ 9.07768115e-02],
#         [ 7.68302852e-02],
#         [ 6.91531145e-02],
#         [ 6.09143597e-02],
#         [ 5.71496648e-02],
#         [ 5.29012787e-02],
#         [ 5.17669599e-02],
#         [ 4.84782570e-02],
#         [ 4.68562727e-02],
#         [ 4.49976132e-02],
#         [ 4.19263237e-02],
#         [ 4.14106720e-02],
#         [ 3.98591175e-02],
#         [ 3.70868014e-02],
#         [ 3.62303757e-02],
#         [ 3.28544777e-02],
#         [ 3.23769720e-02],
#         [ 2.97967795e-02],
#         [ 2.81122085e-02],
#         [ 2.60691623e-02],
#         [ 2.48442064e-02],
#         [ 2.43009577e-02],
#         [ 2.40193254e-02],
#         [ 2.28100657e-02],
#         [ 2.17546725e-02],
#         [ 2.19645714e-02],
#         [ 2.04687130e-02],
#         [ 2.14676847e-02],
#         [ 2.26801109e-02],
#         [ 2.29393469e-02],
#         [ 2.09958820e-02],
#         [ 2.03046679e-02],
#         [ 1.98500324e-02],
#         [ 1.86897232e-02],
#         [ 1.67680578e-02],
#         [ 1.48767749e-02],
#         [ 1.55870329e-02],
#         [ 9.52511182e-03],
#         [ 1.27888330e-02]]])
